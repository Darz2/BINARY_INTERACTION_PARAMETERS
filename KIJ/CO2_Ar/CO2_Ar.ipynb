# %%
import time
notebook_start = time.perf_counter()
import numpy as np, pandas as pd, matplotlib.pyplot as plt, matplotlib.ticker as ticker, sys, os, csv, shutil, json
from scipy.optimize import least_squares
from itertools import chain
from si_units import BAR, KELVIN
from pathlib import Path
from feos.eos import EquationOfState, PhaseDiagram
from feos.pcsaft import PcSaftParameters
from feos.eos.estimator import Estimator, Loss, DataSet, Phase
import io, base64

sys.path.append("..")
import PLOT_SETTINGS as ps

plot_dir = Path("PLOTS")
if plot_dir.exists():
    shutil.rmtree(plot_dir)
plot_dir.mkdir()

mixture = "CO2-Ar"
PLOT    = False
npoints = 1000       # for VLE calculations
nfit    = 1000
# deg     = 2

# %%
def eos_from_kij(kij):
    """Returns equation of state (PC-SAFT) for current kij."""
    global parameters
    p = PcSaftParameters.new_binary(parameters.pure_records, kij)
    return EquationOfState.pcsaft(p)

def cost(kij, estimator):
    """Calculates cost function for current parameters."""
    return estimator.cost(eos_from_kij(kij))

def components(mixture):
    global comp1, comp2
    comp1, comp2 = mixture.split("-")
    
    return comp1, comp2

def poly_to_string(coeffs, var="T", name="k_ij"):
    """
    Build a readable polynomial string from np.polyfit coeffs.
    coeffs are in descending powers: [c_n, ..., c_1, c_0]
    """
    deg     = len(coeffs) - 1
    terms   = []
    for i, coef in enumerate(coeffs):
        power = deg - i
        if power == 0:
            terms.append(f"{coef:.6e}")
        elif power == 1:
            terms.append(f"({coef:.6e})*{var}")
        else:
            terms.append(f"({coef:.6e})*{var}^{power}")
    return f"{name}({var}) = " + " + ".join(terms)

def fit_kij_polynomial(df_best_kij, deg, T_col="Temperature_[K]", kij_col="kij"):
    """
    Fit kij(T) with a polynomial of degree 'deg'.

    Returns:
      coeffs  : np.ndarray of coefficients (descending powers)
      kij_func: np.poly1d callable function
    """
    T_data      = df_best_kij[T_col].to_numpy(dtype=float)
    kij_data    = df_best_kij[kij_col].to_numpy(dtype=float)

    # sort by temperature
    order       = np.argsort(T_data)
    T_data      = T_data[order]
    kij_data    = kij_data[order]

    coeffs      = np.polyfit(T_data, kij_data, deg=deg)
    kij_func    = np.poly1d(coeffs)

    print("\nFitted function:")
    print(poly_to_string(coeffs, var="T", name="k_ij"))
    # print("\nnp.poly1d form:\n", kij_func)

    return coeffs, kij_func, T_data, kij_data

def set_custom_xlabel(ax, fontsize=ps.label_fontsize):
    ax.text(0.33, -0.17, r"$x_{\mathrm{CO_2}}$",
        color="blue", fontsize=fontsize,transform=ax.transAxes, ha="right")
    ax.text(0.35, -0.17, r"$,$",
        color="black", fontsize=fontsize,transform=ax.transAxes, ha="center")
    ax.text(0.36, -0.17, r"$y_{\mathrm{CO_2}}$",
        color="red", fontsize=fontsize,transform=ax.transAxes, ha="left")
    ax.text(0.49, -0.17, r"$/ \;[{\mathrm{mol} \; \mathrm{mol}^{-1}}]$",
        color="black", fontsize=fontsize,transform=ax.transAxes, ha="left")
    
def fig_to_b64(fig):
    buf = io.BytesIO()
    fig.savefig(buf, format="png", dpi=150, bbox_inches="tight")
    buf.seek(0)
    return base64.b64encode(buf.read()).decode("utf-8")

# %%
def VLE_PLOT(mixture, data, cols, temperature, kij):

    comp1, comp2    = components(mixture)
    isotherm        = data[data[cols["T"]] == temperature]
    
    if isotherm.empty:
        raise ValueError(f"No data available for T = {temperature} K")

    fig, ax = ps.plot_init()
    i = 0
 
    # Experimental data
    if isotherm[cols["Comp"]].iloc[0] == comp2:
        ax.plot(1-isotherm[cols["x1"]], isotherm[cols["P"]],
            color='blue', marker=ps.markers[i % len(ps.markers)],
            linestyle="", markersize=ps.markersize, markerfacecolor="#56abff", markeredgewidth=ps.markeredgewidth,
            label=isotherm.source.iloc[0] + f" (T = {temperature} K)")

        ax.plot(1-isotherm[cols["y1"]], isotherm[cols["P"]],
            color='red', marker=ps.markers[i % len(ps.markers)],
            linestyle="", markersize=ps.markersize, markerfacecolor="#FF5656", markeredgewidth=ps.markeredgewidth,)
    else:
        ax.plot(isotherm[cols["x1"]], isotherm[cols["P"]],
            color='blue', marker=ps.markers[i % len(ps.markers)],
            linestyle="", markersize=ps.markersize,markerfacecolor="#56abff", markeredgewidth=ps.markeredgewidth,
            label=isotherm.source.iloc[0] + f" (T = {temperature} K)")

        ax.plot(isotherm[cols["y1"]], isotherm[cols["P"]],
            color='red', marker=ps.markers[i % len(ps.markers)],
            linestyle="", markersize=ps.markersize, markerfacecolor="#FF5656", markeredgewidth=ps.markeredgewidth,)

    # PC-SAFT predictions
    vle = PhaseDiagram.binary_vle(eos_from_kij(kij),temperature * KELVIN, npoints)

    ax.plot(vle.vapor.molefracs[:, 1], vle.vapor.pressure / BAR,
        color='red', linewidth=ps.linewidth, linestyle="-",
        label=fr"PC-SAFT ($k_{{ij}} = {kij:.3f}$)")

    ax.plot(vle.liquid.molefracs[:, 1], vle.liquid.pressure / BAR,
        color='blue', linewidth=ps.linewidth, linestyle="-")

    ax.minorticks_on()
    ymax = (vle.liquid.pressure / BAR).max()
    
    ax.xaxis.set_major_locator(ticker.MultipleLocator(0.1))
    ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.05))
    
    if ymax > 140:
        ax.yaxis.set_major_locator(ticker.MultipleLocator(40))
        ax.yaxis.set_minor_locator(ticker.MultipleLocator(20))
    else:
        ax.yaxis.set_major_locator(ticker.MultipleLocator(20))
        ax.yaxis.set_minor_locator(ticker.MultipleLocator(10))

    # ax.set_xlabel(r"$x_{\mathrm{CO_2}}$, $y_{\mathrm{CO_2}}$", fontsize=ps.label_fontsize)
    set_custom_xlabel(ax, fontsize=ps.label_fontsize)
    ax.set_ylabel(r"$P$ / [bar]", fontsize=ps.label_fontsize)
    ax.set_xlim(min(vle.vapor.molefracs[:, 1].min(), vle.liquid.molefracs[:, 1].min())- 0.1, 1.1)
    ax.set_ylim( (vle.liquid.pressure / BAR).min()/1.3, (vle.liquid.pressure / BAR).max() * 1.3)

    ps.style_legend(ax,loc='upper right',ncol=1,borderaxespad=1.0,frame=False)

    legend = ax.get_legend()
    for handle in legend.legend_handles:
        handle.set_color("black")
        handle.set_markerfacecolor("black")
        handle.set_markeredgecolor("black")
        
    ps.save_plot(fig, f"vle_T{int(temperature)}K_kij{kij:.3f}")

# %%
parameters  = PcSaftParameters.from_json(["argon", "carbon dioxide"], "../parameters_08.json")
pcsaft      = EquationOfState.pcsaft(parameters)
parameters
# Out:
# |component|molarweight|$m$|$\sigma$|$\varepsilon$|$\mu$|$Q$|$\kappa_{AB}$|$\varepsilon_{AB}$|$N_A$|$N_B$|$N_C$|
# |-|-|-|-|-|-|-|-|-|-|-|-|
# |argon|39.962|1|3.37751|117.80903|-|-|-|-|0|0|0|
# |carbon dioxide|43.99|2.53096|2.57855|153.31864|-|-|-|-|0|0|0|

# %%
data = pd.read_excel("VLE_CO2_AR.xlsx", sheet_name=0)
cols = {
        "P": data.columns[0],
        "x1": data.columns[1],
        "y1": data.columns[2],
        "T": data.columns[3],
        'Comp': data.columns[5]
        }

# mask = (data[cols["T"]].between(238,250))
# data = data[~mask].reset_index(drop=True)

# print(data.tail())
# print(data.head())
comp1, comp2    = components(mixture)
print(f"Components: {comp1}, {comp2}")
print(data[cols["T"]].unique())
# Out:
# Components: CO2, Ar
# [213.14 223.07 233.32 238.03 243.12 253.28 263.13 273.26 283.14]

# %%
if PLOT == True:
    for T in data[cols["T"]].unique():
        VLE_PLOT(mixture, data, cols, T, 0)
        plt.show()

# %%
kij_distance = []

for T in data[cols["T"]].unique():

    isotherm = data[data[cols["T"]] == T]

    if 'fitted_kij' not in locals() or fitted_kij is None:
        initial_kij = [0.0]
    else:
        initial_kij = [fitted_kij[0]]
    
    if cols['Comp'] in isotherm.columns:
        if isotherm[cols['Comp']].iloc[0] == comp2:
            x = isotherm[cols["x1"]].to_numpy(float)
            y = isotherm[cols["y1"]].to_numpy(float)
        else:
            x = 1- isotherm[cols["x1"]].to_numpy(float)
            y = 1- isotherm[cols["y1"]].to_numpy(float)

    isotherms = [DataSet.binary_phase_diagram(T*KELVIN, isotherm[cols["P"]].values * BAR, x, y, npoints)]

    estimator = Estimator(isotherms, weights=[1], losses=[Loss.linear()])
    
    fitted_kij = least_squares(cost, initial_kij, bounds=[-0.5, 0.5], args=(estimator,), verbose=2).x
    
    kij_distance.append(fitted_kij[0])

    mard_distance = estimator.mean_absolute_relative_difference(eos_from_kij(fitted_kij)) * 100

    kij_file = os.path.join("PLOTS", "kij_all.csv")

    write_header = not os.path.exists(kij_file)
    with open(kij_file, "a", newline="") as f:
        writer = csv.writer(f)
        if write_header:
            writer.writerow(["Optimization type", "Temperature_[K]", "kij", "MARD_percentage"])
        writer.writerow(["distance", T, fitted_kij[0], mard_distance.mean()])

    print(f"\033[1mOptimized kij value at T = {T} K: {fitted_kij[0]:.6f}\033[0m")
    
    print(f"MARD (distance,   k_ij = {fitted_kij[0]:>6.4}) = {mard_distance.mean():>8.4} %")
# Out:
# /tmp/ipykernel_157233/896817863.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   p = PcSaftParameters.new_binary(parameters.pure_records, kij)
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         9.4367e-05                                    2.06e-03
#        1              2         8.1751e-06      8.62e-05       3.83e-02       3.38e-05
#        2              3         8.1595e-06      1.56e-08       4.93e-04       4.19e-08
#        3              4         8.1595e-06      3.02e-14       7.09e-07       3.01e-09
# `gtol` termination condition is satisfied.
# Function evaluations 4, initial cost 9.4367e-05, final cost 8.1595e-06, first-order optimality 3.01e-09.
# Optimized kij value at T = 213.14 K: 0.037817
# MARD (distance,   k_ij = 0.03782) =    1.184 %
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         5.3662e-06                                    7.67e-05
#        1              2         4.9254e-06      4.41e-07       6.26e-03       1.00e-06
#        2              3         4.9253e-06      9.47e-11       9.44e-05       1.17e-07
#        3              4         4.9253e-06      8.93e-13       9.70e-06       1.69e-08
#        4              5         4.9253e-06      2.39e-14       1.59e-06       3.14e-09
# `gtol` termination condition is satisfied.
# Function evaluations 5, initial cost 5.3662e-06, final cost 4.9253e-06, first-order optimality 3.14e-09.
# Optimized kij value at T = 223.07 K: 0.031646
# MARD (distance,   k_ij = 0.03165) =    1.602 %
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.8380e-06                                    6.56e-06
#        1              2         1.8331e-06      4.92e-09       8.23e-04       2.01e-07
#        2              3         1.8330e-06      6.00e-12       2.86e-05       1.51e-08
#        3              4         1.8330e-06      2.38e-14       1.89e-06       1.51e-09
# `gtol` termination condition is satisfied.
# Function evaluations 4, initial cost 1.8380e-06, final cost 1.8330e-06, first-order optimality 1.51e-09.
# Optimized kij value at T = 233.32 K: 0.030850
# MARD (distance,   k_ij = 0.03085) =    1.055 %
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         3.6640e-06                                    4.92e-05
#        1              2         3.3288e-06      3.35e-07       7.31e-03       3.13e-07
#        2              3         3.3287e-06      1.47e-11       5.35e-05       5.74e-08
#        3              4         3.3287e-06      3.96e-13       8.90e-06       9.74e-09
# `gtol` termination condition is satisfied.
# Function evaluations 4, initial cost 3.6640e-06, final cost 3.3287e-06, first-order optimality 9.74e-09.
# Optimized kij value at T = 238.03 K: 0.023586
# MARD (distance,   k_ij = 0.02359) =     1.57 %
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.0523e-05                                    9.30e-05
#        1              2         1.0075e-05      4.48e-07       3.71e-03       3.37e-05
#        2              3         1.0004e-05      7.09e-08       2.12e-03       1.01e-06
#        3              4         1.0004e-05      9.20e-11       6.42e-05       2.00e-07
#        4              5         1.0004e-05      1.98e-12       1.27e-05       3.56e-08
#        5              6         1.0004e-05      7.27e-14       2.43e-06       7.35e-09
# `gtol` termination condition is satisfied.
# Function evaluations 6, initial cost 1.0523e-05, final cost 1.0004e-05, first-order optimality 7.35e-09.
# Optimized kij value at T = 243.12 K: 0.017690
# MARD (distance,   k_ij = 0.01769) =    1.731 %
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.4383e-06                                    4.17e-05
#        1              2         1.9273e-06      5.11e-07       1.20e-02       9.15e-07
#        2              3         1.9271e-06      1.98e-10       2.46e-04       2.86e-08
#        3              4         1.9271e-06      2.12e-13       8.66e-06       6.28e-09
# `gtol` termination condition is satisfied.
# Function evaluations 4, initial cost 2.4383e-06, final cost 1.9271e-06, first-order optimality 6.28e-09.
# Optimized kij value at T = 253.28 K: 0.029492
# MARD (distance,   k_ij = 0.02949) =    1.086 %
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.5016e-05                                    1.42e-04
#        1              2         1.1084e-05      3.93e-06       2.27e-02       1.55e-04
#        2             10         1.1084e-05      7.32e-12       6.68e-08       1.24e-04
#        3             16         1.1084e-05      0.00e+00       0.00e+00       1.24e-04
# `xtol` termination condition is satisfied.
# Function evaluations 16, initial cost 1.5016e-05, final cost 1.1084e-05, first-order optimality 1.24e-04.
# Optimized kij value at T = 263.13 K: 0.006802
# MARD (distance,   k_ij = 0.006802) =    2.011 %
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         7.6590e-06                                    3.19e-05
#        1              2         7.3049e-06      3.54e-07       6.80e-03       1.91e-05
#        2              3         7.1045e-06      2.00e-07       1.05e-02       5.64e-07
#        3              4         7.1043e-06      1.69e-10       3.03e-04       7.93e-09
# `gtol` termination condition is satisfied.
# Function evaluations 4, initial cost 7.6590e-06, final cost 7.1043e-06, first-order optimality 7.93e-09.
# Optimized kij value at T = 273.26 K: 0.023832
# MARD (distance,   k_ij = 0.02383) =    1.519 %
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         8.9619e-06                                    3.63e-05
#        1              2         8.3936e-06      5.68e-07       1.66e-02       3.09e-06
#        2              3         8.3901e-06      3.53e-09       1.41e-03       3.63e-07
#        3              4         8.3901e-06      5.80e-11       1.93e-04       1.16e-07
#        4              5         8.3901e-06      2.90e-12       5.27e-05       4.83e-08
#        5              6         8.3900e-06      6.94e-13       2.57e-05       2.74e-08
#        6              7         8.3900e-06      1.63e-13       1.25e-05       1.14e-08
#        7              8         8.3900e-06      3.86e-14       6.08e-06       6.51e-09
# `gtol` termination condition is satisfied.
# Function evaluations 8, initial cost 8.9619e-06, final cost 8.3900e-06, first-order optimality 6.51e-09.
# Optimized kij value at T = 283.14 K: 0.039139
# MARD (distance,   k_ij = 0.03914) =    1.115 %

# %%
if PLOT == True:
    for T, kij in zip(data[cols["T"]].unique(), kij_distance):
        VLE_PLOT(mixture, data, cols, T, kij)
        plt.show()

# %%
kij_mu = []

for T in data[cols["T"]].unique():

    isotherm = data[data[cols["T"]] == T]

    if 'fitted_kij' not in locals() or fitted_kij is None:
        initial_kij = [0.0]
    else:
        initial_kij = [fitted_kij[0]]
    
    if cols['Comp'] in isotherm.columns:
        if isotherm[cols['Comp']].iloc[0] == comp2:
            x = isotherm[cols["x1"]].to_numpy(float)
            y = isotherm[cols["y1"]].to_numpy(float)
        else:
            x = 1- isotherm[cols["x1"]].to_numpy(float)
            y = 1- isotherm[cols["y1"]].to_numpy(float)
    
    isotherms = [DataSet.binary_vle_chemical_potential(np.array([T]*len(isotherm)) *KELVIN, 
        isotherm[cols["P"]].values * BAR, x, y)]

    estimator_mu = Estimator(isotherms, weights=[1]*3, losses=[Loss.linear()]*3)

    fitted_kij_mu = least_squares(cost, initial_kij, bounds=[-0.5, 0.5], args=(estimator_mu,), verbose=2).x

    kij_mu.append(fitted_kij_mu[0])

    mard_mu = estimator_mu.mean_absolute_relative_difference(eos_from_kij(fitted_kij_mu)) * 100

    kij_file = os.path.join("PLOTS", "kij_all.csv")

    write_header = not os.path.exists(kij_file)
    with open(kij_file, "a", newline="") as f:
        writer = csv.writer(f)
        if write_header:
            writer.writerow(["Optimization type", "Temperature_[K]", "kij", "MARD_percentage"])
        writer.writerow(["chemical potential", T, fitted_kij_mu[0], mard_mu.mean()])

    print(f"\033[1mOptimized kij value at T = {T} K: {fitted_kij_mu[0]:.6f}\033[0m")
    print(f"MARD (chem. pot., k_ij = {fitted_kij_mu[0]:>6.4}) = {mard_mu.mean():>8.4} %")
# Out:
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.8233e-06                                    1.01e-04
#        1              2         2.0186e-06      8.05e-07       7.18e-03       2.97e-06
#        2              3         2.0179e-06      7.34e-10       2.22e-04       3.37e-08
#        3              4         2.0179e-06      9.49e-14       2.53e-06       3.69e-10
# `gtol` termination condition is satisfied.
# Function evaluations 4, initial cost 2.8233e-06, final cost 2.0179e-06, first-order optimality 3.69e-10.
# Optimized kij value at T = 213.14 K: 0.046546
# MARD (chem. pot., k_ij = 0.04655) =    1.502 %
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         5.4398e-06                                    1.26e-04
#        1              2         2.7988e-06      2.64e-06       1.83e-02       7.23e-06
#        2              3         2.7891e-06      9.67e-09       1.16e-03       1.35e-07
#        3              4         2.7891e-06      3.40e-12       2.19e-05       2.14e-09
# `gtol` termination condition is satisfied.
# Function evaluations 4, initial cost 5.4398e-06, final cost 2.7891e-06, first-order optimality 2.14e-09.
# Optimized kij value at T = 223.07 K: 0.058634
# MARD (chem. pot., k_ij = 0.05863) =     3.33 %
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.9841e-06                                    6.06e-05
#        1              2         1.2172e-06      7.67e-07       1.12e-02       2.64e-06
#        2              3         1.2156e-06      1.55e-09       5.20e-04       4.78e-08
#        3              4         1.2156e-06      5.12e-13       9.46e-06       8.03e-10
# `gtol` termination condition is satisfied.
# Function evaluations 4, initial cost 1.9841e-06, final cost 1.2156e-06, first-order optimality 8.03e-10.
# Optimized kij value at T = 233.32 K: 0.050874
# MARD (chem. pot., k_ij = 0.05087) =      2.3 %
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.4277e-06                                    4.10e-05
#        1              2         1.9001e-06      5.28e-07       1.13e-02       2.23e-06
#        2              3         1.8984e-06      1.68e-09       6.60e-04       6.52e-08
#        3              4         1.8984e-06      1.45e-12       1.94e-05       1.80e-09
# `gtol` termination condition is satisfied.
# Function evaluations 4, initial cost 2.4277e-06, final cost 1.8984e-06, first-order optimality 1.80e-09.
# Optimized kij value at T = 238.03 K: 0.051120
# MARD (chem. pot., k_ij = 0.05112) =    2.875 %
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.5102e-06                                    3.36e-05
#        1              2         1.3099e-06      2.00e-07       5.32e-03       1.23e-06
#        2              3         1.3097e-06      2.80e-10       2.02e-04       2.91e-08
#        3              4         1.3097e-06      1.57e-13       4.79e-06       6.72e-10
# `gtol` termination condition is satisfied.
# Function evaluations 4, initial cost 1.5102e-06, final cost 1.3097e-06, first-order optimality 6.72e-10.
# Optimized kij value at T = 243.12 K: 0.044664
# MARD (chem. pot., k_ij = 0.04466) =    1.615 %
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         7.6729e-07                                    1.50e-05
#        1              2         6.9041e-07      7.69e-08       4.57e-03       5.30e-07
#        2              3         6.9032e-07      9.91e-11       1.67e-04       1.27e-08
#        3              4         6.9032e-07      5.68e-14       3.99e-06       2.97e-10
# `gtol` termination condition is satisfied.
# Function evaluations 4, initial cost 7.6729e-07, final cost 6.9032e-07, first-order optimality 2.97e-10.
# Optimized kij value at T = 253.28 K: 0.043881
# MARD (chem. pot., k_ij = 0.04388) =    1.772 %
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         6.9402e-07                                    1.22e-06
#        1              2         6.9350e-07      5.21e-10       3.79e-04       4.19e-08
#        2              3         6.9350e-07      6.13e-13       1.30e-05       1.40e-09
# `gtol` termination condition is satisfied.
# Function evaluations 3, initial cost 6.9402e-07, final cost 6.9350e-07, first-order optimality 1.40e-09.
# Optimized kij value at T = 263.13 K: 0.039532
# MARD (chem. pot., k_ij = 0.03953) =    1.354 %
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         7.2012e-07                                    9.84e-06
#        1              2         6.9680e-07      2.33e-08       2.47e-03       3.05e-07
#        2              3         6.9677e-07      2.24e-11       7.66e-05       8.62e-09
# `gtol` termination condition is satisfied.
# Function evaluations 3, initial cost 7.2012e-07, final cost 6.9677e-07, first-order optimality 8.62e-09.
# Optimized kij value at T = 273.26 K: 0.036590
# MARD (chem. pot., k_ij = 0.03659) =    1.487 %
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.6645e-06                                    9.40e-05
#        1              2         1.0789e-06      1.59e-06       1.68e-02       4.45e-06
#        2              3         1.0756e-06      3.26e-09       7.31e-04       2.00e-07
#        3              4         1.0756e-06      6.57e-12       3.28e-05       8.98e-09
# `gtol` termination condition is satisfied.
# Function evaluations 4, initial cost 2.6645e-06, final cost 1.0756e-06, first-order optimality 8.98e-09.
# Optimized kij value at T = 283.14 K: 0.021611
# MARD (chem. pot., k_ij = 0.02161) =    1.148 %
# /tmp/ipykernel_157233/896817863.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   p = PcSaftParameters.new_binary(parameters.pure_records, kij)

# %%
if PLOT == True:
    for T, kij in zip(data[cols["T"]].unique(), kij_mu):
        VLE_PLOT(mixture, data, cols, T, kij)
        plt.show()

# %%
kij_pressure = []

for T in data[cols["T"]].unique():

    isotherm = data[data[cols["T"]] == T]

    if 'fitted_kij' not in locals() or fitted_kij is None:
        initial_kij = [0.0]
    else:
        initial_kij = [fitted_kij[0]]
        
    if cols['Comp'] in isotherm.columns:
        if isotherm[cols['Comp']].iloc[0] == comp2:
            x = isotherm[cols["x1"]].to_numpy(float)
            y = isotherm[cols["y1"]].to_numpy(float)
        else:
            x = 1- isotherm[cols["x1"]].to_numpy(float)
            y = 1- isotherm[cols["y1"]].to_numpy(float)

    isotherms = [[DataSet.binary_vle_pressure(np.array([T]*len(isotherm))*KELVIN, 
                isotherm[cols["P"]].values * BAR, x,Phase.Liquid)],]
    
    estimator_p = Estimator(list(chain.from_iterable(isotherms)), weights=[1]*6, losses=[Loss.linear()]*6)
    
    try:
        res = least_squares(cost, initial_kij, bounds=(-1, 1), args=(estimator_p,), verbose=2)

        kij_value = float(np.atleast_1d(res.x)[0])
        kij_pressure.append(kij_value)

        mard_value = float(estimator_p.mean_absolute_relative_difference(
            eos_from_kij(np.array([kij_value]))) * 100)

    except Exception as e:
        print("Optimization failed:", e)
        kij_value = np.nan
        kij_pressure.append(np.nan)
        mard_value = np.nan
    
    kij_file = os.path.join("PLOTS", "kij_all.csv")

    write_header = not os.path.exists(kij_file)
    with open(kij_file, "a", newline="") as f:
        writer = csv.writer(f)
        if write_header:
            writer.writerow(["Optimization type", "Temperature_[K]", "kij", "MARD_percentage"])
        writer.writerow(["pressure", T, kij_value, mard_value])

    print(f"\033[1mOptimized kij value at T = {T} K: {kij_value:.6f}\033[0m")
    print(f"MARD (pressure,   k_ij = {kij_value:>6.4}) = {mard_value:>8.4} %")
# Out:
# /tmp/ipykernel_157233/896817863.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   p = PcSaftParameters.new_binary(parameters.pure_records, kij)
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.8107e-05                                    1.74e-03
#        1              2         2.4954e-05      3.15e-06       3.66e-03       1.78e-04
#        2              3         2.4930e-05      2.39e-08       2.93e-04       6.94e-06
#        3              4         2.4930e-05      4.36e-11       1.26e-05       3.54e-07
#        4              5         2.4930e-05      9.55e-14       5.91e-07       1.62e-08
# `ftol` termination condition is satisfied.
# Function evaluations 5, initial cost 2.8107e-05, final cost 2.4930e-05, first-order optimality 1.62e-08.
# Optimized kij value at T = 213.14 K: 0.042515
# MARD (pressure,   k_ij = 0.04251) =    8.589 %
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.1801e-05                                    7.12e-04
#        1              2         1.9387e-05      2.41e-06       7.09e-03       1.14e-04
# /tmp/ipykernel_157233/2049560164.py:31: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   mard_value = float(estimator_p.mean_absolute_relative_difference(
#        2              3         1.9345e-05      4.24e-08       8.39e-04       7.11e-06
#        3              4         1.9345e-05      2.02e-10       5.89e-05       6.08e-07
#        4              5         1.9345e-05      1.23e-12       4.59e-06       4.21e-08
#        5              6         1.9345e-05      7.22e-15       3.47e-07       3.18e-09
# `gtol` termination condition is satisfied.
# Function evaluations 6, initial cost 2.1801e-05, final cost 1.9345e-05, first-order optimality 3.18e-09.
# Optimized kij value at T = 223.07 K: 0.045445
# MARD (pressure,   k_ij = 0.04545) =    11.69 %
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         6.8620e-06                                    1.02e-04
#        1              2         6.7828e-06      7.92e-08       1.55e-03       5.13e-06
#        2              3         6.7827e-06      1.65e-10       6.94e-05       1.73e-07
#        3              4         6.7827e-06      2.20e-13       2.54e-06       6.87e-09
# `gtol` termination condition is satisfied.
# Function evaluations 4, initial cost 6.8620e-06, final cost 6.7827e-06, first-order optimality 6.87e-09.
# Optimized kij value at T = 233.32 K: 0.040622
# MARD (pressure,   k_ij = 0.04062) =    7.391 %
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         6.8777e-06                                    1.13e-04
#        1              2         6.7657e-06      1.12e-07       2.12e-03       2.13e-06
#        2              3         6.7657e-06      4.82e-11       4.53e-05       8.15e-08
#        3              4         6.7657e-06      6.09e-14       1.61e-06       2.68e-09
# `gtol` termination condition is satisfied.
# Function evaluations 4, initial cost 6.8777e-06, final cost 6.7657e-06, first-order optimality 2.68e-09.
# Optimized kij value at T = 238.03 K: 0.037058
# MARD (pressure,   k_ij = 0.03706) =    8.284 %
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.5498e-05                                    5.95e-04
#        1              2         1.4055e-05      1.44e-06       5.16e-03       2.17e-06
#        2              3         1.4055e-05      2.16e-11       2.12e-05       5.72e-08
#        3              4         1.4055e-05      1.70e-14       5.97e-07       2.03e-09
# `gtol` termination condition is satisfied.
# Function evaluations 4, initial cost 1.5498e-05, final cost 1.4055e-05, first-order optimality 2.03e-09.
# Optimized kij value at T = 243.12 K: 0.033963
# MARD (pressure,   k_ij = 0.03396) =    7.601 %
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.4407e-06                                    2.54e-05
#        1              2         2.4313e-06      9.42e-09       7.80e-04       2.17e-07
#        2              3         2.4313e-06      8.11e-13       7.28e-06       3.03e-09
# `gtol` termination condition is satisfied.
# Function evaluations 3, initial cost 2.4407e-06, final cost 2.4313e-06, first-order optimality 3.03e-09.
# Optimized kij value at T = 253.28 K: 0.038367
# MARD (pressure,   k_ij = 0.03837) =    4.574 %
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         8.8179e-06                                    4.52e-04
#        1              2         6.2453e-06      2.57e-06       1.19e-02       1.47e-05
#        2              3         6.2420e-06      3.30e-09       4.68e-04       1.82e-07
#        3              4         6.2420e-06      5.63e-13       6.13e-06       2.72e-09
# `gtol` termination condition is satisfied.
# Function evaluations 4, initial cost 8.8179e-06, final cost 6.2420e-06, first-order optimality 2.72e-09.
# Optimized kij value at T = 263.13 K: 0.026774
# MARD (pressure,   k_ij = 0.02677) =    6.016 %
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.2301e-06                                    8.31e-05
#        1              2         2.0114e-06      2.19e-07       5.49e-03       9.85e-07
#        2              3         2.0114e-06      3.30e-11       6.98e-05       6.56e-09
# `gtol` termination condition is satisfied.
# Function evaluations 3, initial cost 2.2301e-06, final cost 2.0114e-06, first-order optimality 6.56e-09.
# Optimized kij value at T = 273.26 K: 0.033583
# MARD (pressure,   k_ij = 0.03358) =    3.417 %
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.5759e-06                                    1.51e-04
#        1              2         1.0461e-06      5.30e-07       7.25e-03       2.98e-06
#        2              3         1.0458e-06      2.22e-10       1.54e-04       9.08e-10
# `gtol` termination condition is satisfied.
# Function evaluations 3, initial cost 1.5759e-06, final cost 1.0458e-06, first-order optimality 9.08e-10.
# Optimized kij value at T = 283.14 K: 0.031731
# MARD (pressure,   k_ij = 0.03173) =     1.65 %

# %%
if PLOT == True:
    for T, kij in zip(data[cols["T"]].unique(), kij_pressure):
        try:
            VLE_PLOT(mixture, data, cols, T, kij)
            plt.show()
        except Exception as e:
            print(f"Error plotting VLE for T={T} K and kij={kij}: {e}")
            plt.close()
            continue

# %%
## KIJ Interpolation/Extrapolation
df_KIJ      = pd.read_csv("PLOTS/kij_all.csv")

# # To take the minimum MARD for each temperature, regardless of optimization type
idx         = df_KIJ.groupby("Temperature_[K]")["MARD_percentage"].idxmin()
df_best_kij = df_KIJ.loc[idx].reset_index(drop=True)
T_min       = df_best_kij["Temperature_[K]"].min()
T_max       = df_best_kij["Temperature_[K]"].max()
kij_mean    = float(df_best_kij["kij"].mean())
kij_std     = float(df_best_kij["kij"].std(ddof=1))

# Choosing kij based on the distance optimization type, as it is more consistent across temperatures and has lower MARD values compared to chemical potential and pressure optimizations
# df_best_kij = (df_KIJ[df_KIJ["Optimization type"] == "distance"].sort_values("Temperature_[K]").reset_index(drop=True))
print(df_best_kij)

coeffs_lin,  kij_func_lin,  T_data, kij_data = fit_kij_polynomial(df_best_kij, deg=1)
coeffs_quad, kij_func_quad, T_data, kij_data = fit_kij_polynomial(df_best_kij, deg=2)
# Out:
#     Optimization type  Temperature_[K]       kij  MARD_percentage
# 0            distance           213.14  0.037817         1.184057
# 1            distance           223.07  0.031646         1.602298
# 2            distance           233.32  0.030850         1.054619
# 3            distance           238.03  0.023586         1.570410
# 4  chemical potential           243.12  0.044664         1.614789
# 5            distance           253.28  0.029492         1.085984
# 6  chemical potential           263.13  0.039532         1.353535
# 7  chemical potential           273.26  0.036590         1.486868
# 8            distance           283.14  0.039139         1.114581
#
# Fitted function:
# k_ij(T) = (7.829945e-05)*T + 1.546872e-02
#
# Fitted function:
# k_ij(T) = (3.782747e-06)*T^2 + (-1.802400e-03)*T + 2.474145e-01

# %%
T_fit           = np.linspace(T_data.min(), T_data.max(), nfit)
kij_fit_lin     = kij_func_lin(T_fit)
kij_fit_quad    = kij_func_quad(T_fit)

fig1, ax1 = ps.plot_init()

ax1.plot(df_best_kij["Temperature_[K]"], df_best_kij["kij"],linestyle="",
    linewidth=ps.linewidth,marker=ps.markers[0],markersize=ps.markersize, markerfacecolor="#FF5656",
    markeredgewidth=ps.markeredgewidth,color=ps.colors[0],
    label=r"$k_{ij}$")

# Constant: mean and SD as horizontal band
ax1.axhline(kij_mean, color="gray", linewidth=ps.linewidth, linestyle=":",
    label=rf"Mean $k_{{ij}}$ = {kij_mean:.4f}")
ax1.axhspan(kij_mean - kij_std, kij_mean + kij_std,
    alpha=0.15, color="gray",
    label=rf"$\pm$SD = {kij_std:.4f}")

# Linear fit
ax1.plot(T_fit, kij_fit_lin, color="steelblue", linewidth=ps.linewidth, linestyle="--",
    label=r"1$^{\mathrm{st}}$-order")

# Quadratic fit
ax1.plot(T_fit, kij_fit_quad, color="k", linewidth=ps.linewidth, linestyle="-.",
    label=r"2$^{\mathrm{nd}}$-order")
    
ax1.set_xlabel(r"$T\,/\, \mathrm{[K]}$", fontsize=ps.label_fontsize)
ax1.set_ylabel(r"$k_{ij}\, / \, [-]$", fontsize=ps.label_fontsize)
# ps.style_legend(ax1, loc='lower left', ncol=1, borderaxespad=1.0, frame=True)

ax1.minorticks_on()
ax1.yaxis.set_major_locator(ticker.MultipleLocator(0.02))
ax1.yaxis.set_minor_locator(ticker.MultipleLocator(0.01))
ax1.xaxis.set_major_locator(ticker.MultipleLocator(10))
ax1.xaxis.set_minor_locator(ticker.MultipleLocator(5))

ax1.set_xlim(T_data.min() - 5, T_data.max() + 5)
ax1.set_ylim(kij_data.min() - 0.02, kij_data.max() + 0.02)

fig1.tight_layout()
ps.save_plot(fig1, f"kij_{mixture.replace('-','-')}_vs_T")
plt.show()

# Separate legend figure
handles, labels = ax1.get_legend_handles_labels()
fig_leg, ax_leg = plt.subplots(figsize=(4, 2))
ax_leg.axis("off")
ax_leg.legend(handles, labels, loc="center", ncol=1, frameon=True)
fig_leg.tight_layout()
ps.save_plot(fig_leg, f"kij_{mixture.replace('-', '-')}_legend")
plt.show()

# %%
out = {
    "T_min": T_min,
    "T_max": T_max,
    "constant": {
        "deg"   : 0,
        "mean"  : kij_mean,
        "std"   : kij_std
    },
    "linear": {
        "deg"   : 1,
        "coeffs": [float(c) for c in coeffs_lin]
    },
    "quadratic": {
        "deg"   : 2,
        "coeffs": [float(c) for c in coeffs_quad]
    },
    "plots": {
        "kij_vs_T" : fig_to_b64(fig1),
        "legend"   : fig_to_b64(fig_leg)
    }
}

Path("KIJ.json").write_text(json.dumps(out, indent=2), encoding="utf-8")
# Out:
# 37130

# %%
notebook_end = time.perf_counter()
print(f"Total notebook runtime: {notebook_end - notebook_start:.2f} s")
# Out:
# Total notebook runtime: 53.05 s
